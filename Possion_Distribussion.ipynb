# %% [markdown]
# <a href="https://colab.research.google.com/github/Mangai2024/Mangai2024/blob/main/Possion_Distribussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Poisson Distribution**

# %%
The Poisson distribution is a probability distribution used to model the number of events that
 occur within a fixed interval of time or space, provided these events happen at a constant
average rate and independently of each other.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# On average,i make 5 dosa's in  10 minutes. I want to calculate the Probability of exactly 8 in a specific 10 minutes interval

# %%
The probability mass function (PMF) of the Poisson distribution is:

# %%
import numpy as np
Lambda_value=5 #Average number of dosa's per 10 minutes

# %%
k=8 # Number of dosa's we want the probability for

# %%
Poisson_Probability=(np.power(Lambda_value,k)*np.exp(-Lambda_value))/np.math.factorial(k)
# Out:
# <ipython-input-13-323b89f32c50>:1: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   Poisson_Probability=(np.power(Lambda_value,k)*np.exp(-Lambda_value))/np.math.factorial(k)

# %%
print(f"The Probability of exactly {k}  i want to make the dosa's in 10 minutes is {Poisson_Probability}")
# Out:
# The Probability of exactly 8  i want to make the dosa's in 10 minutes is 0.06527803934815875

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Parameters for Poisson distribution
lambda_value = 5 # Average number of Dosa's per 10 minutes
size = 1000  # Number of random samples

# Generate random samples from a Poisson distribution
poisson_samples = np.random.poisson(lam=lambda_value, size=size)

# Plot histogram using seaborn
sns.histplot(poisson_samples, bins=10, kde=False, color='skyblue', stat='probability')
plt.xlabel('Number of Dosa(k)')
plt.ylabel('Probability')
plt.title(f'Histogram of Poisson Distribution (λ={lambda_value})')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
k=np.random.poisson(lam=5,size=10000)

# %%
sns.kdeplot(k)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Scenario:
# A call center receives an average of 5 calls per hour. The manager wants to calculate:
#
# The probability of receiving exactly 3 calls in an hour.
# The probability of receiving fewer than 4 calls in an hour.
# The probability of receiving 7 or more calls in an hour.

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt
import seaborn as sns
# Parameters for the Poisson distribution
lmbda = 5  # Average number of calls per hour

# 1. Probability of exactly 3 calls
probability_exact_3 = poisson.pmf(3, lmbda)
print(f"Probability of exactly 3 calls in an hour: {probability_exact_3:.4f}")

# 2. Probability of fewer than 4 calls
probability_fewer_than_4 = poisson.cdf(3, lmbda)
print(f"Probability of fewer than 4 calls in an hour: {probability_fewer_than_4:.4f}")

# 3. Probability of 7 or more calls
probability_7_or_more = 1 - poisson.cdf(6, lmbda)
print(f"Probability of 7 or more calls in an hour: {probability_7_or_more:.4f}")
# Out:
# Probability of exactly 3 calls in an hour: 0.1404
# Probability of fewer than 4 calls in an hour: 0.2650
# Probability of 7 or more calls in an hour: 0.2378

# %%
k=np.random.poisson(lam=3,size=10000)

# %%
sns.kdeplot(k)
# Out:
# <Axes: ylabel='Density'>

# %%
# Plot histogram using seaborn
sns.histplot(k, kde=False, color='skyblue', stat='probability')  # Replace poisson_samples with k
plt.xlabel('Number of Calls(k)')
plt.ylabel('Probability')
plt.title(f'Histogram of Poisson Distribution (λ=7)') # Replace lambda_value with 5 as per prior code
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
